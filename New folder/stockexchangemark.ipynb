# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file_path=r"C:\Users\Ahmed\Downloads\DATASETS\StockExchange\indexData.csv"

# %%
df = pd.read_csv(file_path)

# %%
df
# Out:
#        Index        Date         Open         High          Low        Close  \
# 0        NYA  1965-12-31   528.690002   528.690002   528.690002   528.690002
# 1        NYA  1966-01-03   527.210022   527.210022   527.210022   527.210022
# 2        NYA  1966-01-04   527.840027   527.840027   527.840027   527.840027
# 3        NYA  1966-01-05   531.119995   531.119995   531.119995   531.119995
# 4        NYA  1966-01-06   532.070007   532.070007   532.070007   532.070007
# ...      ...         ...          ...          ...          ...          ...
# 112452  N100  2021-05-27  1241.119995  1251.910034  1241.119995  1247.069946
# 112453  N100  2021-05-28  1249.469971  1259.209961  1249.030029  1256.599976
# 112454  N100  2021-05-31  1256.079956  1258.880005  1248.140015  1248.930054
# 112455  N100  2021-06-01  1254.609985  1265.660034  1254.609985  1258.579956
# 112456  N100  2021-06-02  1258.489990  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112457 entries, 0 to 112456
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Index      112457 non-null  object
#  1   Date       112457 non-null  object
#  2   Open       110253 non-null  float64
#  3   High       110253 non-null  float64
#  4   Low        110253 non-null  float64
#  5   Close      110253 non-null  float64
#  6   Adj Close  110253 non-null  float64
#  7   Volume     110253 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 6.9+ MB

# %%
df.describe()
# Out:
#                 Open           High            Low          Close  \
# count  110253.000000  110253.000000  110253.000000  110253.000000
# mean     7658.515222    7704.372961    7608.000422    7657.545872
# std      9011.478913    9066.638548    8954.506981    9011.510444
# min        54.869999      54.869999      54.869999      54.869999
# 25%      1855.030029    1864.510010    1843.979980    1855.060059
# 50%      5194.089844    5226.279785    5154.049805    5194.750000
# 75%     10134.299810   10207.820310   10060.349610   10134.830080
# max     68775.062500   69403.750000   68516.992190   68775.062500
#
#            Adj Close        Volume
# count  110253.000000  1.102530e+05
# mean     7657.351729  1.273975e+09
# std      9011.608900  4.315783e+09
# min        54.869999  0.000000e+00
# 25%      1854.179565  0.000000e+00
# 50%      5194.750000  4.329000e+05
# 75%     10134.830080  1.734314e+08
# max     68775.062500  9.440374e+10

# %%
df.isnull().sum()
# Out:
# Index           0
# Date            0
# Open         2204
# High         2204
# Low          2204
# Close        2204
# Adj Close    2204
# Volume       2204
# dtype: int64

# %%
df.shape
# Out:
# (112457, 8)

# %%
df.notna()
# Out:
#         Index  Date  Open  High   Low  Close  Adj Close  Volume
# 0        True  True  True  True  True   True       True    True
# 1        True  True  True  True  True   True       True    True
# 2        True  True  True  True  True   True       True    True
# 3        True  True  True  True  True   True       True    True
# 4        True  True  True  True  True   True       True    True
# ...       ...   ...   ...   ...   ...    ...        ...     ...
# 112452   True  True  True  True  True   True       True    True
# 112453   True  True  True  True  True   True       True    True
# 112454   True  True  True  True  True   True       True    True
# 112455   True  True  True  True  True   True       True    True
# 112456   True  True  True  True  True   True       True    True
#
# [112457 rows x 8 columns]

# %%
ar.plot()
plt.title("Stock Exchage")
# Out:
# Text(0.5, 1.0, 'Stock Exchage')

# %%
ar.plot.scatter(x="Open", y="Close", color="blue", alpha=0.6)
plt.xlabel("Open")
# Out:
# Text(0.5, 0, 'Open')

# %%
axs=df.plot.area(figsize=(12,4), subplots=True)

# %%
df[["Open","High","Low","Close","Adj Close"]].groupby("Open").mean()
# Out:
#                       High           Low         Close     Adj Close
# Open
# 54.869999        54.869999     54.869999     54.869999     54.869999
# 55.160000        55.160000     55.160000     55.160000     55.160000
# 55.480000        55.480000     55.480000     55.480000     55.480000
# 55.669998        55.669998     55.669998     55.669998     55.669998
# 56.130001        56.130001     56.130001     56.130001     56.130001
# ...                    ...           ...           ...           ...
# 68516.992190  68924.992190  68516.992190  68775.062500  68775.062500
# 68519.531250  69043.101560  68373.640630  68377.226560  68377.226560
# 68655.960940  68655.960940  67941.453130  68516.992190  68516.992190
# 68698.781250  68802.687500  68094.281250  68094.281250  68094.281250
# 68775.062500  68775.062500  67675.593750  68209.859380  68209.859380
#
# [102021 rows x 4 columns]

# %%
df.sort_values(by="Date")
# Out:
#             Index        Date          Open          High           Low  \
# 92450        N225  1965-01-05   1257.719971   1257.719971   1257.719971
# 92451        N225  1965-01-06   1263.989990   1263.989990   1263.989990
# 92452        N225  1965-01-07   1274.270020   1274.270020   1274.270020
# 92453        N225  1965-01-08   1286.430054   1286.430054   1286.430054
# 92454        N225  1965-01-11           NaN           NaN           NaN
# ...           ...         ...           ...           ...           ...
# 112455       N100  2021-06-01   1254.609985   1265.660034   1254.609985
# 112456       N100  2021-06-02   1258.489990   1263.709961   1258.239990
# 106948       N225  2021-06-02  28730.810550  29003.550780  28565.830080
# 58054   399001.SZ  2021-06-02  15044.940430  15051.209960  14793.740230
# 106949       N225  2021-06-03  28890.390630  29157.160160  28879.150390
#
#                Close     Adj Close       Volume
# 92450    1257.719971   1257.719971          0.0
# ...

# %%
df.sort_values(by="Index", ascending=True)
# Out:
#            Index        Date          Open          High           Low  \
# 40511  000001.SS  2017-12-11   3290.488037   3322.674072   3288.294922
# 39369  000001.SS  2013-04-03   2232.694092   2241.340088   2217.251953
# 39368  000001.SS  2013-04-02   2234.900879   2253.420898   2220.438965
# 39367  000001.SS  2013-04-01   2229.459961   2243.947998   2227.313965
# 39366  000001.SS  2013-03-29   2238.485107   2246.867920   2228.812988
# ...          ...         ...           ...           ...           ...
# 86052       TWII  2005-03-01   6227.419922   6260.319824   6207.779785
# 86051       TWII  2005-02-28           NaN           NaN           NaN
# 86050       TWII  2005-02-25   6195.240234   6233.529785   6192.379883
# 86059       TWII  2005-03-10   6207.859863   6215.470215   6168.759766
# 89621       TWII  2019-08-01  10773.059570  10773.250000  10714.730470
#
#               Close     Adj Close     Volume
# 40511   3322.196045   3322.196045   132000.0
# ...

# %%
N225 = df[df["Index"] == "NYA"]
ar=N225
ar.plot(label="Index", color="blue")
plt.title("N225 Stock Exchange")
# Out:
# Text(0.5, 1.0, 'N225 Stock Exchange')

# %%
df.count()
# Out:
# Index        112457
# Open         110253
# High         110253
# Low          110253
# Close        110253
# Adj Close    110253
# Volume       110253
# dtype: int64

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
print(df.index)
print(df.index.dtype)
# Out:
# DatetimeIndex(['1965-12-31', '1966-01-03', '1966-01-04', '1966-01-05',
#                '1966-01-06', '1966-01-07', '1966-01-10', '1966-01-11',
#                '1966-01-12', '1966-01-13',
#                ...
#                '2021-05-20', '2021-05-21', '2021-05-24', '2021-05-25',
#                '2021-05-26', '2021-05-27', '2021-05-28', '2021-05-31',
#                '2021-06-01', '2021-06-02'],
#               dtype='datetime64[ns]', name='Date', length=112457, freq=None)
# datetime64[ns]

# %%
df_interpolated=df.interpolate(method="time")

# %%
df_interpolated.isnull().sum()
# Out:
# Index        0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Volume'], label='Original Data')
plt.plot(df_interpolated.index, df_interpolated['Volume'], label='Interpolated Data', linestyle='--')
plt.title('Stock Prices with Interpolation')
plt.legend()
plt.grid(True)
plt.show()

# %%
df.isnull().sum()
# Out:
# Index           0
# Open         2204
# High         2204
# Low          2204
# Close        2204
# Adj Close    2204
# Volume       2204
# dtype: int64

# %%
from sklearn.impute import KNNImputer
df_encoded = pd.get_dummies(df, columns=['Index'])

# Extract numeric columns for imputation
df_numeric = df_encoded.select_dtypes(include=[np.number])

# Apply KNN Imputer
imputer = KNNImputer(n_neighbors=2)
df_imputed = pd.DataFrame(imputer.fit_transform(df_numeric), index=df.index, columns=df_numeric.columns)

df_imputed = df_imputed.reindex(df_interpolated.index, method='ffill')  # Forward fill to align

# %%
df_imputed.isnull().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Close'], label='Original Data')
plt.plot(df_imputed.index, df_imputed['Close'], label='Imputted Data', linestyle='--')
plt.title('Stock Prices with KNN Imputer')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df_imputed.index, df_imputed['Close'], label='Imputed Data')
plt.plot(df_interpolated.index, df_interpolated['Close'], label='Interpolated Data', linestyle='--')
plt.title('Stock Prices with Interpolation')
plt.legend()
plt.grid(True)
plt.show()

# %%
data=df_interpolated
# Convert the Date column to datetime and set it as index
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)
# Feature Engineering
data['Return'] = data['Close'].pct_change()
data['Moving_Avg_10'] = data['Close'].rolling(window=10).mean()
data['Moving_Avg_50'] = data['Close'].rolling(window=50).mean()
data['Volatility'] = data['Return'].rolling(window=10).std()
data.dropna(inplace=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler
# Target Variable: Predict whether the stock price will go up (1) or down (0) the next day
data['Target'] = (data['Close'].shift(-1) > data['Close']).astype(int)
data.dropna(inplace=True)  # Drop the last row as it has no target

# Features and Target
features = ['Return', 'Moving_Avg_10', 'Moving_Avg_50', 'Volatility']
X = data[features]
y = data['Target']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %%
features = ['Return', 'Moving_Avg_10', 'Moving_Avg_50', 'Volatility']
X = data[features]
y = data['Target']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# 1. Bagging with Random Forest
print("Bagging with Random Forest")

# Initialize and train the Random Forest model
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Make predictions
rf_predictions = rf_model.predict(X_test)

# %%
# Evaluate the model
rf_accuracy = accuracy_score(y_test, rf_predictions)
print(f"Random Forest Accuracy: {rf_accuracy:.4f}")
print("Random Forest Classification Report:")
print(classification_report(y_test, rf_predictions))

# 2. Boosting with Gradient Boosting
print("\nBoosting with Gradient Boosting")

# Initialize and train the Gradient Boosting model
gb_model = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, random_state=42)
gb_model.fit(X_train, y_train)

# Make predictions
gb_predictions = gb_model.predict(X_test)

# Evaluate the model
gb_accuracy = accuracy_score(y_test, gb_predictions)
print(f"Gradient Boosting Accuracy: {gb_accuracy:.4f}")
print("Gradient Boosting Classification Report:")
print(classification_report(y_test, gb_predictions))
# Out:
# Random Forest Accuracy: 0.5227
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.49      0.46      0.47     15924
#            1       0.54      0.58      0.56     17799
#
#     accuracy                           0.52     33723
#    macro avg       0.52      0.52      0.52     33723
# weighted avg       0.52      0.52      0.52     33723
#
#
# Boosting with Gradient Boosting
# Gradient Boosting Accuracy: 0.5391
# Gradient Boosting Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.56      0.12      0.20     15924
#            1       0.54      0.91      0.68     17799
#
#     accuracy                           0.54     33723
#    macro avg       0.55      0.52      0.44     33723
# weighted avg       0.55      0.54      0.45     33723
